# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulhakimarrauf-sys/Abdul-Hakim-Arrauf_Aljabar-Matrix/blob/main/Norms_and_Unit_Vectors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'**SOAL NO 1 (Norms and Unit Vectors)**'
# Out:
# '**SOAL NO 1 (Norms and Unit Vectors)**'

# %%
import numpy as np

# %%
# buat vector x dengan ukuran 3x1
x = np.array([[19],
              [20],
              [10]])
x
# Out:
# array([[19],
#        [20],
#        [10]])

# %%
# hitung nilai L2 norm dari vector x
(19**2 + 20**2 + 10**2)**(1/2)
# Out:
# 29.34280150224242

# %%
"""**SOAL NO 2 (Norms and Unit Vectors)**"""
# Out:
# '**SOAL NO 2 (Norms and Unit Vectors)**'

# %%
# buat vector v dengan elemen (3,4)
v = np.array([3, 4])
print(f'Vektor asli: {v}')
# Out:
# Vektor asli: [3 4]

# %%
# hitung nilai L2 norm dari vector v
norm = np.linalg.norm(v)
print(f'Panjang vektor: {norm}')
# Out:
# Panjang vektor: 5.0

# %%
# tampilkan unit vector dari vector v
unit_v = v / norm
print(f'Unit vektor: {unit_v}')
# Out:
# Unit vektor: [0.6 0.8]

# %%
# hitung panjang unit vector dari vector v
print(f'Panjang unit vektor: {np.linalg.norm(unit_v)}')
# Out:
# Panjang unit vektor: 1.0
