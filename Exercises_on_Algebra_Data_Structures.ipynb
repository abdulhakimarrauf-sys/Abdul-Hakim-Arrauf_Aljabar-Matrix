# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulhakimarrauf-sys/Abdul-Hakim-Arrauf_Aljabar-Matrix/blob/main/Exercises_on_Algebra_Data_Structures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# selesaikan soal berikut
# What is the transpose of this vector?
# [25]
# [2]
# [-3]
# [-23]
import numpy as np

x = np.array([[25],
      [2],
      [-3],
      [-23]])
x

x_t = x.T
x_t
# Out:
# array([[ 25,   2,  -3, -23]])
